# %% [markdown]
# # Random Forrest Classifier

# %% [markdown]
# ## The overall video ratings for `Observer`(V1), `Strategy`(V2) and `MVC`(V3) patterns will be classified separately based on each learning style dimension scores below...
# * A/R_Score
# * S/I_Score
# * Vi/Vb_Score
# * S/G_Score

# %% [markdown]
# The classifiers were trained using `GridSearchCV`, a hyperparamater tuning technique, and the training set was split into `10-fold cross validation`. The average scores were collected after each classifier was 'train test split' a few times (various random states) with train-test.

# %% [markdown]
# # Importing the necessary libraries

# %%
### For data manipulation and visualisation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

### To Encode the data
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.preprocessing import LabelEncoder

### Machine Learning
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE,RandomOverSampler

# %% [markdown]
# # Reading the dataset

# %%
pd.set_option('display.max_columns', None)
training = pd.read_csv('BDP_Cleaned.csv') #dataset after feature selection process for 5-Level Classification

# %% [markdown]
# # Dropping all irrelevant features
# * `Time_Day_Watched` of all design patterns as features have already been extracted
# * `Gender` as male and females are imbalanced and does not provide any useful insights
# * `Duration` of each video as watch status and percentage duration have already been extracted from it

# %%
training.drop(['Time_Day_Watched_(V1-1)',
         'Time_Day_Watched_(V1-2)',
         'Time_Day_Watched_(V1-3)',
         'Time_Day_Watched_(V1-4)',
         'Time_Day_Watched_(V2-1)',
         'Time_Day_Watched_(V2-2)',
         'Time_Day_Watched_(V2-3)',
         'Time_Day_Watched_(V2-4)',
         'Time_Day_Watched_(V3-1)',
         'Time_Day_Watched_(V3-2)',
         'Time_Day_Watched_(V3-3)',
         'Time_Day_Watched_(V3-4)',
               'Gender',
               "V1-1_(1)",
               "V1-2_(1)",
               "V1-3_(1)",
               "V1-4_(1)",
               "V2-1_(2)",
               "V2-1_(2)",
               "V2-2_(2)",
               "V2-3_(2)",
               "V2-4_(2)",
               "V3-1_(3)",
               "V3-2_(3)",
               "V3-3_(3)",
               "V3-4_(3)",
               
        ], axis = 1,inplace = True)

# %% [markdown]
# # Getting numerical and categorical features for further tuning scaling and fitting

# %%
numerical_feats = training.dtypes[training.dtypes != "object"].index
categorical_feats = training.dtypes[training.dtypes == "object"].index

# %%
print("*"*100)
print(training[numerical_feats].columns)
print("*"*100)
print(training[categorical_feats].columns)
print("*"*100)
training.columns
# Out:
# ****************************************************************************************************
# Index(['V1_PercentWatched', 'V2_PercentWatched', 'V3_PercentWatched',
#        'A/R_Score', 'Active', 'Reflective', 'S/I_Score', 'Sensing',
#        'Intuitive', 'Vi/Vb_Score', 'Visual', 'Verbal', 'S/G_Score',
#        'Sequential', 'Global', 'Quiz'],
#       dtype='object')
# ****************************************************************************************************
# Index(['CGPA_Class', 'Student_Rating_(V1-1)', 'Student_Rating_(V1-2)',
#        'Student_Rating_(V1-3)', 'Student_Rating_(V1-4)', 'Overall_Rating_V1',
#        'Watch_Status_V1', 'Student_Rating_(V2-1)', 'Student_Rating_(V2-2)',
#        'Student_Rating_(V2-3)', 'Student_Rating_(V2-4)', 'Overall_Rating_V2',
#        'Watch_Status_V2', 'Student_Rating_(V3-1)', 'Student_Rating_(V3-2)',
#        'Student_Rating_(V3-3)', 'Student_Rating_(V3-4)', 'Overall_Rating_V3',
#        'Watch_Status_V3', 'part_day_V1-1', 'part_day_V1-2', 'part_day_V1-3',
#        'part_day_V1-4', 'part_day_V2-1', 'part_day_V2-2', 'part_day_V2-3',
#        'part_day_V2-4', 'part_day_V3-1', 'part_day_V3-2', 'part_day_V3-3',
#        'part_day_V3-4'],
#       dtype='object')
# ****************************************************************************************************
# Index(['CGPA_Class', 'Student_Rating_(V1-1)', 'Student_Rating_(V1-2)',
#        'Student_Rating_(V1-3)', 'Student_Rating_(V1-4)', 'Overall_Rating_V1',
#        'Watch_Status_V1', 'V1_PercentWatched', 'Student_Rating_(V2-1)',
#        'Student_Rating_(V2-2)', 'Student_Rating_(V2-3)',
#        'Student_Rating_(V2-4)', 'Overall_Rating_V2', 'Watch_Status_V2',
#        'V2_PercentWatched', 'Student_Rating_(V3-1)', 'Student_Rating_(V3-2)',
#        'Student_Rating_(V3-3)', 'Student_Rating_(V3-4)', 'Overall_Rating_V3',
#        'Watch_Status_V3', 'V3_PercentWatched', 'A/R_Score', 'Active',
#        'Reflective', 'S/I_Score', 'Sensing', 'Intuitive', 'Vi/Vb_Score',
#        'Visual', 'Verbal', 'S/G_Score', 'Sequential', 'Global', 'Quiz',
#        'part_day_V1-1', 'part_day_V1-2', 'part_day_V1-3', 'part_day_V1-4',
#        'part_day_V2-1', 'part_day_V2-2', 'part_day_V2-3', 'part_day_V2-4',
#        'part_day_V3-1', 'part_day_V3-2', 'part_day_V3-3', 'part_day_V3-4'],
#       dtype='object')

# %% [markdown]
# # Using MinMax Scaler to scale data from 0 to 1 since numerical features are not normally distributed

# %%
scaler = MinMaxScaler()
training['Quiz'] = scaler.fit_transform(training[['Quiz']])
training['A/R_Score'] = scaler.fit_transform(training[['A/R_Score']])
training['S/I_Score'] = scaler.fit_transform(training[['S/I_Score']])
training['Vi/Vb_Score'] = scaler.fit_transform(training[['Vi/Vb_Score']])
training['S/G_Score'] = scaler.fit_transform(training[['S/G_Score']])
training['V1_PercentWatched'] = scaler.fit_transform(training[['V1_PercentWatched']])
training['V2_PercentWatched'] = scaler.fit_transform(training[['V2_PercentWatched']])
training['V3_PercentWatched'] = scaler.fit_transform(training[['V3_PercentWatched']])
training.head()
# Out:
#     CGPA_Class Student_Rating_(V1-1) Student_Rating_(V1-2)  \
# 0  2.67 - 3.32             Excellent          Satisfactory
# 1  2.67 - 3.32             Very Good             Very Good
# 2  2.67 - 3.32             Excellent          Satisfactory
# 3  3.67 - 4.00             Excellent             Very Good
# 4  2.67 - 3.32             Very Good             Very Good
#
#   Student_Rating_(V1-3) Student_Rating_(V1-4) Overall_Rating_V1  \
# 0             Very Good             Very Good         Very Good
# 1             Very Good             Very Good         Very Good
# 2             Very Good          Satisfactory         Very Good
# 3             Excellent             Excellent         Excellent
# 4          Satisfactory             Very Good         Very Good
#
#   Watch_Status_V1  V1_PercentWatched Student_Rating_(V2-1)  \
# 0       Completed           0.747748             Very Good
# 1       Completed           0.747748             Very Good
# 2       Completed           0.747748             Very Good
# 3       Completed           0.747748             Excellent
# 4       Completed           0.747748             Excellent
#
#   Student_Rating_(V2-2) Student_Rating_(V2-3) Student_Rating_(V2-4)  \
# 0          Satisfactory             Very Good             Very Good
# 1             Very Good             Very Good             Very Good
# 2          Satisfactory             Very Good             Excellent
# 3             Excellent             Very Good             Excellent
# 4             Very Good             Very Good          Satisfactory
#
#   Overall_Rating_V2 Watch_Status_V2  V2_PercentWatched Student_Rating_(V3-1)  \
# 0         Very Good       Completed           0.440789             Excellent
# 1         Very Good       Completed           0.440789             Very Good
# 2         Very Good       Completed           0.440789             Excellent
# 3         Excellent       Rewatched           0.618421             Excellent
# 4         Very Good       Completed           0.440789             Very Good
#
#   Student_Rating_(V3-2) Student_Rating_(V3-3) Student_Rating_(V3-4)  \
# 0             Very Good             Very Good             Very Good
# 1             Very Good             Very Good             Very Good
# 2             Very Good             Very Good             Very Good
# 3             Excellent             Very Good             Excellent
# 4             Very Good             Excellent             Very Good
#
#   Overall_Rating_V3 Watch_Status_V3  V3_PercentWatched  A/R_Score  Active  \
# 0         Very Good       Completed           0.632653        0.2       1
# 1         Very Good       Rewatched           0.653061        0.2       0
# 2         Very Good       Completed           0.632653        0.0       0
# 3         Excellent       Completed           0.632653        0.2       0
# 4         Very Good       Completed           0.632653        0.2       1
#
#    Reflective  S/I_Score  Sensing  Intuitive  Vi/Vb_Score  Visual  Verbal  \
# 0           0       0.25        1          0          0.6       1       0
# 1           1       1.00        1          0          0.6       1       0
# 2           1       0.75        1          0          0.6       1       0
# 3           1       0.25        1          0          0.6       1       0
# 4           0       0.00        1          0          0.4       1       0
#
#    S/G_Score  Sequential  Global   Quiz part_day_V1-1 part_day_V1-2  \
# 0        0.0           1       0  1.000         night         night
# 1        0.2           0       1  0.750      midnight         night
# 2        0.2           0       1  0.500         night         night
# 3        0.0           1       0  0.375      midnight      midnight
# 4        0.2           0       1  0.750     afternoon     afternoon
#
#   part_day_V1-3 part_day_V1-4 part_day_V2-1 part_day_V2-2 part_day_V2-3  \
# 0         night         night         night         night         night
# 1         night         night         night         night         night
# 2     afternoon     afternoon         night         night     afternoon
# 3      midnight     afternoon      midnight      midnight      midnight
# 4     afternoon     afternoon     afternoon     afternoon     afternoon
#
#   part_day_V2-4 part_day_V3-1 part_day_V3-2 part_day_V3-3 part_day_V3-4
# 0         night         night         night         night         night
# 1         night         night         night         night         night
# 2     afternoon         night         night     afternoon     afternoon
# 3      midnight      midnight      midnight      midnight      midnight
# 4     afternoon     afternoon     afternoon     afternoon     afternoon

# %% [markdown]
# # Encoding categorical values using label encoder

# %%
features =  ["CGPA_Class",
             "Overall_Rating_V1",
             "Overall_Rating_V2",
             "Overall_Rating_V3",
             "Watch_Status_V1",
             "Watch_Status_V2",
             "Watch_Status_V3",
             "part_day_V1-1",
             "part_day_V1-2",
             "part_day_V1-3",
             "part_day_V1-4",
             "part_day_V2-1",
             "part_day_V2-2",
             "part_day_V2-3",
             "part_day_V2-4",
             "part_day_V3-1",
             "part_day_V3-2",
             "part_day_V3-3",
             "part_day_V3-4"]

for i in features:
    training.loc[:,i] = LabelEncoder().fit_transform(training.loc[:,i])

# %% [markdown]
# ### Overall_rating_V1 `(Observer)` for `Active/Reflective` learners (60 Train - 40 Test) | (70 Train - 30 Test) | (80 Train - 20 Test)

# %%
temp = []
rand_states = [7,69,101]
y = training[['Overall_Rating_V1']]
X = training[['CGPA_Class',
              'Watch_Status_V1',
              'A/R_Score','Quiz','part_day_V1-1', 'part_day_V1-2', 'part_day_V1-3', 'part_day_V1-4']]

oversample = RandomOverSampler(sampling_strategy='all')
X, y = oversample.fit_resample(X, y)


for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {'n_estimators': [200, 400],
                      'max_features': ['auto', 'sqrt', 'log2'],
                      'criterion' :['gini', 'entropy']}

        model = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, n_jobs=-1, cv=10, verbose=1)
        model.fit(X_train, y_train.values.ravel())
        pred = model.predict(X_test)
        
        acc = accuracy_score(y_test,pred)
        pre = precision_score(y_test, pred, average='weighted')
        recall = recall_score(y_test, pred, average='weighted')
        f1 = f1_score(y_test, pred, average='weighted')
        param = model.best_params_
        
        temp.append([i,j,acc,pre,recall,f1,param])
        
df_A = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score','Best Param'],data=temp)
df_A
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#     Test Size  Random State  Accuracy  Precision    Recall  F1 Score  \
# 0         0.5             7  0.707317   0.695708  0.707317  0.697466
# 1         0.5            69  0.650407   0.616460  0.650407  0.617468
# 2         0.5           101  0.715447   0.704101  0.715447  0.703891
# 3         0.4             7  0.734694   0.731650  0.734694  0.712596
# 4         0.4            69  0.785714   0.805800  0.785714  0.768513
# 5         0.4           101  0.724490   0.737059  0.724490  0.715724
# 6         0.3             7  0.702703   0.674324  0.702703  0.675709
# 7         0.3            69  0.810811   0.801031  0.810811  0.799142
# 8         0.3           101  0.729730   0.746335  0.729730  0.723371
# 9         0.2             7  0.693878   0.639366  0.693878  0.648102
# 10        0.2            69  0.877551   0.880143  0.877551  0.868387
# 11        0.2           101  0.816327   0.834354  0.816327  0.813910
#
#                                            Best Param
# 0   {'criterion': 'gini', 'max_features': 'log2', ...
# 1   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 2   {'criterion': 'entropy', 'max_features': 'log2...
# 3   {'criterion': 'gini', 'max_features': 'auto', ...
# 4   {'criterion': 'gini', 'max_features': 'log2', ...
# 5   {'criterion': 'entropy', 'max_features': 'auto...
# 6   {'criterion': 'entropy', 'max_features': 'sqrt...
# 7   {'criterion': 'gini', 'max_features': 'auto', ...
# 8   {'criterion': 'gini', 'max_features': 'log2', ...
# 9   {'criterion': 'gini', 'max_features': 'auto', ...
# 10  {'criterion': 'gini', 'max_features': 'log2', ...
# 11  {'criterion': 'gini', 'max_features': 'log2', ...

# %%
df_A.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.795918   0.784621  0.795918  0.776799
# 0.3        0.747748   0.740563  0.747748  0.732741
# 0.4        0.748299   0.758170  0.748299  0.732278
# 0.5        0.691057   0.672090  0.691057  0.672942

# %% [markdown]
# ### Overall_rating_V1 `(Observer)` for `Sensing/Intuitive` learners (60 Train - 40 Test) | (70 Train - 30 Test) | (80 Train - 20 Test)MVC

# %%
temp = []
rand_states = [7,69,101]
y = training[['Overall_Rating_V1']]
X = training[['CGPA_Class',
              'Watch_Status_V1',
              'S/I_Score','Quiz','part_day_V1-1', 'part_day_V1-2', 'part_day_V1-3', 'part_day_V1-4']]

oversample = RandomOverSampler(sampling_strategy='all')
X, y = oversample.fit_resample(X, y)


for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {'n_estimators': [200, 400],
                      'max_features': ['auto', 'sqrt', 'log2'],
                      'criterion' :['gini', 'entropy']}

        model = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, n_jobs=-1, cv=10, verbose=1)
        model.fit(X_train, y_train.values.ravel())
        pred = model.predict(X_test)
        
        acc = accuracy_score(y_test,pred)
        pre = precision_score(y_test, pred, average='weighted')
        recall = recall_score(y_test, pred, average='weighted')
        f1 = f1_score(y_test, pred, average='weighted')
        param = model.best_params_
        
        temp.append([i,j,acc,pre,recall,f1,param])
        
df_B = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score','Best Param'],data=temp)
df_B
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#     Test Size  Random State  Accuracy  Precision    Recall  F1 Score  \
# 0         0.5             7  0.739837   0.746665  0.739837  0.729617
# 1         0.5            69  0.707317   0.713375  0.707317  0.697275
# 2         0.5           101  0.747967   0.761072  0.747967  0.747862
# 3         0.4             7  0.826531   0.836909  0.826531  0.816163
# 4         0.4            69  0.775510   0.790276  0.775510  0.773691
# 5         0.4           101  0.765306   0.772799  0.765306  0.758862
# 6         0.3             7  0.797297   0.794337  0.797297  0.778171
# 7         0.3            69  0.824324   0.814830  0.824324  0.816508
# 8         0.3           101  0.783784   0.812125  0.783784  0.774692
# 9         0.2             7  0.714286   0.705642  0.714286  0.694606
# 10        0.2            69  0.857143   0.851992  0.857143  0.852195
# 11        0.2           101  0.877551   0.895343  0.877551  0.873377
#
#                                            Best Param
# 0   {'criterion': 'gini', 'max_features': 'log2', ...
# 1   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 2   {'criterion': 'entropy', 'max_features': 'sqrt...
# 3   {'criterion': 'gini', 'max_features': 'auto', ...
# 4   {'criterion': 'entropy', 'max_features': 'sqrt...
# 5   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 6   {'criterion': 'gini', 'max_features': 'auto', ...
# 7   {'criterion': 'gini', 'max_features': 'log2', ...
# 8   {'criterion': 'entropy', 'max_features': 'log2...
# 9   {'criterion': 'entropy', 'max_features': 'sqrt...
# 10  {'criterion': 'gini', 'max_features': 'auto', ...
# 11  {'criterion': 'gini', 'max_features': 'log2', ...

# %%
df_B.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.816327   0.817659  0.816327  0.806726
# 0.3        0.801802   0.807097  0.801802  0.789791
# 0.4        0.789116   0.799995  0.789116  0.782905
# 0.5        0.731707   0.740371  0.731707  0.724918

# %% [markdown]
# ### Overall_rating_V1 `(Observer)` for `Visual/Verbal` learners (60 Train - 40 Test) | (70 Train - 30 Test) | (80 Train - 20 Test)

# %%
temp = []
rand_states = [7,69,101]
y = training[['Overall_Rating_V1']]
X = training[['CGPA_Class',
              'Watch_Status_V1',
              'Vi/Vb_Score','Quiz','part_day_V1-1', 'part_day_V1-2', 'part_day_V1-3', 'part_day_V1-4']]

oversample = RandomOverSampler(sampling_strategy='all')
X, y = oversample.fit_resample(X, y)


for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {'n_estimators': [200, 400],
                      'max_features': ['auto', 'sqrt', 'log2'],
                      'criterion' :['gini', 'entropy']}

        model = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, n_jobs=-1, cv=10, verbose=1)
        model.fit(X_train, y_train.values.ravel())
        pred = model.predict(X_test)
        
        acc = accuracy_score(y_test,pred)
        pre = precision_score(y_test, pred, average='weighted')
        recall = recall_score(y_test, pred, average='weighted')
        f1 = f1_score(y_test, pred, average='weighted')
        param = model.best_params_
        
        temp.append([i,j,acc,pre,recall,f1,param])
        
df_C = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score','Best Param'],data=temp)
df_C
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#     Test Size  Random State  Accuracy  Precision    Recall  F1 Score  \
# 0         0.5             7  0.715447   0.713873  0.715447  0.706913
# 1         0.5            69  0.634146   0.639880  0.634146  0.624480
# 2         0.5           101  0.715447   0.714644  0.715447  0.710682
# 3         0.4             7  0.755102   0.748703  0.755102  0.749345
# 4         0.4            69  0.775510   0.801135  0.775510  0.771348
# 5         0.4           101  0.744898   0.754066  0.744898  0.735218
# 6         0.3             7  0.716216   0.719598  0.716216  0.706384
# 7         0.3            69  0.837838   0.846701  0.837838  0.836273
# 8         0.3           101  0.797297   0.823575  0.797297  0.790409
# 9         0.2             7  0.714286   0.727691  0.714286  0.708225
# 10        0.2            69  0.857143   0.869666  0.857143  0.857143
# 11        0.2           101  0.897959   0.925118  0.897959  0.888911
#
#                                            Best Param
# 0   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 1   {'criterion': 'entropy', 'max_features': 'sqrt...
# 2   {'criterion': 'gini', 'max_features': 'log2', ...
# 3   {'criterion': 'entropy', 'max_features': 'sqrt...
# 4   {'criterion': 'gini', 'max_features': 'auto', ...
# 5   {'criterion': 'entropy', 'max_features': 'auto...
# 6   {'criterion': 'gini', 'max_features': 'log2', ...
# 7   {'criterion': 'entropy', 'max_features': 'auto...
# 8   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 9   {'criterion': 'entropy', 'max_features': 'auto...
# 10  {'criterion': 'gini', 'max_features': 'auto', ...
# 11  {'criterion': 'gini', 'max_features': 'auto', ...

# %%
df_C.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.823129   0.840825  0.823129  0.818093
# 0.3        0.783784   0.796625  0.783784  0.777688
# 0.4        0.758503   0.767968  0.758503  0.751970
# 0.5        0.688347   0.689466  0.688347  0.680691

# %% [markdown]
# ### Overall_rating_V1 `(Observer)` for `Sequential/Global` learners (60 Train - 40 Test) | (70 Train - 30 Test) | (80 Train - 20 Test)

# %%
temp = []
rand_states = [7,69,101]
y = training[['Overall_Rating_V1']]
X = training[['CGPA_Class',
              'Watch_Status_V1',
              'S/G_Score','Quiz','part_day_V1-1', 'part_day_V1-2', 'part_day_V1-3', 'part_day_V1-4']]

oversample = RandomOverSampler(sampling_strategy='all')
X, y = oversample.fit_resample(X, y)


for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {'n_estimators': [200, 400],
                      'max_features': ['auto', 'sqrt', 'log2'],
                      'criterion' :['gini', 'entropy']}

        model = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, n_jobs=-1, cv=10, verbose=1)
        model.fit(X_train, y_train.values.ravel())
        pred = model.predict(X_test)
        
        acc = accuracy_score(y_test,pred)
        pre = precision_score(y_test, pred, average='weighted')
        recall = recall_score(y_test, pred, average='weighted')
        f1 = f1_score(y_test, pred, average='weighted')
        param = model.best_params_
        
        temp.append([i,j,acc,pre,recall,f1,param])
        
df_D = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score','Best Param'],data=temp)
df_D
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#     Test Size  Random State  Accuracy  Precision    Recall  F1 Score  \
# 0         0.5             7  0.723577   0.714548  0.723577  0.716909
# 1         0.5            69  0.650407   0.659787  0.650407  0.632575
# 2         0.5           101  0.747967   0.747768  0.747967  0.738323
# 3         0.4             7  0.734694   0.723820  0.734694  0.724556
# 4         0.4            69  0.775510   0.776276  0.775510  0.762835
# 5         0.4           101  0.704082   0.731732  0.704082  0.696603
# 6         0.3             7  0.689189   0.669630  0.689189  0.675890
# 7         0.3            69  0.797297   0.783835  0.797297  0.786873
# 8         0.3           101  0.770270   0.782326  0.770270  0.760001
# 9         0.2             7  0.673469   0.643878  0.673469  0.654971
# 10        0.2            69  0.795918   0.779721  0.795918  0.780085
# 11        0.2           101  0.816327   0.837415  0.816327  0.815751
#
#                                            Best Param
# 0   {'criterion': 'entropy', 'max_features': 'sqrt...
# 1   {'criterion': 'entropy', 'max_features': 'auto...
# 2   {'criterion': 'entropy', 'max_features': 'sqrt...
# 3   {'criterion': 'entropy', 'max_features': 'auto...
# 4   {'criterion': 'gini', 'max_features': 'auto', ...
# 5   {'criterion': 'entropy', 'max_features': 'auto...
# 6   {'criterion': 'gini', 'max_features': 'log2', ...
# 7   {'criterion': 'gini', 'max_features': 'auto', ...
# 8   {'criterion': 'entropy', 'max_features': 'auto...
# 9   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 10  {'criterion': 'entropy', 'max_features': 'sqrt...
# 11  {'criterion': 'entropy', 'max_features': 'sqrt...

# %%
df_D.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.761905   0.753671  0.761905  0.750269
# 0.3        0.752252   0.745264  0.752252  0.740922
# 0.4        0.738095   0.743942  0.738095  0.727998
# 0.5        0.707317   0.707367  0.707317  0.695936

# %% [markdown]
# ### Overall_rating_V2 `(Strategy)` for `Active/Reflective` learners (60 Train - 40 Test) | (70 Train - 30 Test) | (80 Train - 20 Test)

# %%
temp = []
rand_states = [7,69,101]
y = training[['Overall_Rating_V2']]
X = training[['CGPA_Class',
              'Watch_Status_V2',
              'A/R_Score','Quiz','part_day_V2-1', 'part_day_V2-2', 'part_day_V2-3', 'part_day_V2-4']]

oversample = RandomOverSampler(sampling_strategy='all')
X, y = oversample.fit_resample(X, y)


for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {'n_estimators': [200, 400],
                      'max_features': ['auto', 'sqrt', 'log2'],
                      'criterion' :['gini', 'entropy']}

        model = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, n_jobs=-1, cv=10, verbose=1)
        model.fit(X_train, y_train.values.ravel())
        pred = model.predict(X_test)
        
        acc = accuracy_score(y_test,pred)
        pre = precision_score(y_test, pred, average='weighted')
        recall = recall_score(y_test, pred, average='weighted')
        f1 = f1_score(y_test, pred, average='weighted')
        param = model.best_params_
        
        temp.append([i,j,acc,pre,recall,f1,param])
        
df_E = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score','Best Param'],data=temp)
df_E
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#     Test Size  Random State  Accuracy  Precision    Recall  F1 Score  \
# 0         0.5             7  0.752000   0.748536  0.752000  0.749475
# 1         0.5            69  0.664000   0.680330  0.664000  0.657534
# 2         0.5           101  0.784000   0.789513  0.784000  0.770503
# 3         0.4             7  0.750000   0.732854  0.750000  0.737329
# 4         0.4            69  0.760000   0.774570  0.760000  0.753870
# 5         0.4           101  0.790000   0.799238  0.790000  0.780259
# 6         0.3             7  0.693333   0.675979  0.693333  0.674871
# 7         0.3            69  0.813333   0.839908  0.813333  0.795923
# 8         0.3           101  0.880000   0.896854  0.880000  0.876839
# 9         0.2             7  0.720000   0.764127  0.720000  0.709117
# 10        0.2            69  0.840000   0.840923  0.840000  0.837643
# 11        0.2           101  0.900000   0.906104  0.900000  0.898586
#
#                                            Best Param
# 0   {'criterion': 'gini', 'max_features': 'log2', ...
# 1   {'criterion': 'gini', 'max_features': 'auto', ...
# 2   {'criterion': 'gini', 'max_features': 'log2', ...
# 3   {'criterion': 'gini', 'max_features': 'log2', ...
# 4   {'criterion': 'gini', 'max_features': 'auto', ...
# 5   {'criterion': 'gini', 'max_features': 'auto', ...
# 6   {'criterion': 'entropy', 'max_features': 'sqrt...
# 7   {'criterion': 'gini', 'max_features': 'auto', ...
# 8   {'criterion': 'entropy', 'max_features': 'auto...
# 9   {'criterion': 'gini', 'max_features': 'auto', ...
# 10  {'criterion': 'entropy', 'max_features': 'sqrt...
# 11  {'criterion': 'entropy', 'max_features': 'sqrt...

# %%
df_E.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.820000   0.837051  0.820000  0.815115
# 0.3        0.795556   0.804247  0.795556  0.782545
# 0.4        0.766667   0.768887  0.766667  0.757153
# 0.5        0.733333   0.739460  0.733333  0.725838

# %% [markdown]
# ### Overall_rating_V2 `(Strategy)` for `Sensing/Intuitive` learners (60 Train - 40 Test) | (70 Train - 30 Test) | (80 Train - 20 Test)

# %%
temp = []
rand_states = [7,69,101]
y = training[['Overall_Rating_V2']]
X = training[['CGPA_Class',
              'Watch_Status_V2',
              'S/I_Score','Quiz','part_day_V2-1', 'part_day_V2-2', 'part_day_V2-3', 'part_day_V2-4']]

oversample = RandomOverSampler(sampling_strategy='all')
X, y = oversample.fit_resample(X, y)


for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {'n_estimators': [200, 400],
                      'max_features': ['auto', 'sqrt', 'log2'],
                      'criterion' :['gini', 'entropy']}

        model = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, n_jobs=-1, cv=10, verbose=1)
        model.fit(X_train, y_train.values.ravel())
        pred = model.predict(X_test)
        
        acc = accuracy_score(y_test,pred)
        pre = precision_score(y_test, pred, average='weighted')
        recall = recall_score(y_test, pred, average='weighted')
        f1 = f1_score(y_test, pred, average='weighted')
        param = model.best_params_
        
        temp.append([i,j,acc,pre,recall,f1,param])
        
df_F = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score','Best Param'],data=temp)
df_F
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#     Test Size  Random State  Accuracy  Precision    Recall  F1 Score  \
# 0         0.5             7  0.784000   0.778092  0.784000  0.780518
# 1         0.5            69  0.664000   0.667736  0.664000  0.649261
# 2         0.5           101  0.768000   0.761579  0.768000  0.754093
# 3         0.4             7  0.800000   0.789523  0.800000  0.792040
# 4         0.4            69  0.740000   0.732074  0.740000  0.725524
# 5         0.4           101  0.760000   0.767363  0.760000  0.749572
# 6         0.3             7  0.786667   0.786268  0.786667  0.765216
# 7         0.3            69  0.773333   0.761728  0.773333  0.764789
# 8         0.3           101  0.840000   0.870932  0.840000  0.835245
# 9         0.2             7  0.760000   0.761571  0.760000  0.738632
# 10        0.2            69  0.860000   0.893889  0.860000  0.853922
# 11        0.2           101  0.860000   0.861905  0.860000  0.857955
#
#                                            Best Param
# 0   {'criterion': 'gini', 'max_features': 'auto', ...
# 1   {'criterion': 'gini', 'max_features': 'log2', ...
# 2   {'criterion': 'entropy', 'max_features': 'log2...
# 3   {'criterion': 'entropy', 'max_features': 'log2...
# 4   {'criterion': 'entropy', 'max_features': 'auto...
# 5   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 6   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 7   {'criterion': 'gini', 'max_features': 'log2', ...
# 8   {'criterion': 'gini', 'max_features': 'auto', ...
# 9   {'criterion': 'gini', 'max_features': 'auto', ...
# 10  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 11  {'criterion': 'gini', 'max_features': 'log2', ...

# %%
df_F.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.826667   0.839122  0.826667  0.816836
# 0.3        0.800000   0.806310  0.800000  0.788417
# 0.4        0.766667   0.762986  0.766667  0.755712
# 0.5        0.738667   0.735802  0.738667  0.727958

# %% [markdown]
# ### Overall_rating_V2 `(Strategy)` for `Visual/Verbal` learners (60 Train - 40 Test) | (70 Train - 30 Test) | (80 Train - 20 Test)

# %%
temp = []
rand_states = [7,69,101]
y = training[['Overall_Rating_V2']]
X = training[['CGPA_Class',
              'Watch_Status_V2',
              'Vi/Vb_Score','Quiz','part_day_V2-1', 'part_day_V2-2', 'part_day_V2-3', 'part_day_V2-4']]

oversample = RandomOverSampler(sampling_strategy='all')
X, y = oversample.fit_resample(X, y)


for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {'n_estimators': [200, 400],
                      'max_features': ['auto', 'sqrt', 'log2'],
                      'criterion' :['gini', 'entropy']}

        model = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, n_jobs=-1, cv=10, verbose=1)
        model.fit(X_train, y_train.values.ravel())
        pred = model.predict(X_test)
        
        acc = accuracy_score(y_test,pred)
        pre = precision_score(y_test, pred, average='weighted')
        recall = recall_score(y_test, pred, average='weighted')
        f1 = f1_score(y_test, pred, average='weighted')
        param = model.best_params_
        
        temp.append([i,j,acc,pre,recall,f1,param])
        
df_G = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score','Best Param'],data=temp)
df_G
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#     Test Size  Random State  Accuracy  Precision    Recall  F1 Score  \
# 0         0.5             7  0.784000   0.768927  0.784000  0.772669
# 1         0.5            69  0.616000   0.637459  0.616000  0.599152
# 2         0.5           101  0.816000   0.827914  0.816000  0.809250
# 3         0.4             7  0.740000   0.717230  0.740000  0.720008
# 4         0.4            69  0.750000   0.756959  0.750000  0.742175
# 5         0.4           101  0.810000   0.833317  0.810000  0.798277
# 6         0.3             7  0.746667   0.735988  0.746667  0.723717
# 7         0.3            69  0.786667   0.790374  0.786667  0.782828
# 8         0.3           101  0.813333   0.809352  0.813333  0.800187
# 9         0.2             7  0.740000   0.733212  0.740000  0.708070
# 10        0.2            69  0.840000   0.906667  0.840000  0.856317
# 11        0.2           101  0.900000   0.897374  0.900000  0.897845
#
#                                            Best Param
# 0   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 1   {'criterion': 'gini', 'max_features': 'auto', ...
# 2   {'criterion': 'gini', 'max_features': 'log2', ...
# 3   {'criterion': 'gini', 'max_features': 'auto', ...
# 4   {'criterion': 'gini', 'max_features': 'log2', ...
# 5   {'criterion': 'entropy', 'max_features': 'auto...
# 6   {'criterion': 'entropy', 'max_features': 'sqrt...
# 7   {'criterion': 'gini', 'max_features': 'log2', ...
# 8   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 9   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 10  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 11  {'criterion': 'gini', 'max_features': 'auto', ...

# %%
df_G.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.826667   0.845751  0.826667  0.820744
# 0.3        0.782222   0.778572  0.782222  0.768911
# 0.4        0.766667   0.769169  0.766667  0.753487
# 0.5        0.738667   0.744767  0.738667  0.727024

# %% [markdown]
# ### Overall_rating_V2 `(Strategy)` for `Sequential/Global` learners (60 Train - 40 Test) | (70 Train - 30 Test) | (80 Train - 20 Test)

# %%
temp = []
rand_states = [7,69,101]
y = training[['Overall_Rating_V2']]
X = training[['CGPA_Class',
              'Watch_Status_V2',
              'S/G_Score','Quiz','part_day_V2-1', 'part_day_V2-2', 'part_day_V2-3', 'part_day_V2-4']]

oversample = RandomOverSampler(sampling_strategy='all')
X, y = oversample.fit_resample(X, y)


for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {'n_estimators': [200, 400],
                      'max_features': ['auto', 'sqrt', 'log2'],
                      'criterion' :['gini', 'entropy']}

        model = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, n_jobs=-1, cv=10, verbose=1)
        model.fit(X_train, y_train.values.ravel())
        pred = model.predict(X_test)
        
        acc = accuracy_score(y_test,pred)
        pre = precision_score(y_test, pred, average='weighted')
        recall = recall_score(y_test, pred, average='weighted')
        f1 = f1_score(y_test, pred, average='weighted')
        param = model.best_params_
        
        temp.append([i,j,acc,pre,recall,f1,param])
        
df_H = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score','Best Param'],data=temp)
df_H
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#     Test Size  Random State  Accuracy  Precision    Recall  F1 Score  \
# 0         0.5             7  0.752000   0.757163  0.752000  0.752517
# 1         0.5            69  0.704000   0.711148  0.704000  0.676175
# 2         0.5           101  0.768000   0.771701  0.768000  0.751173
# 3         0.4             7  0.730000   0.724815  0.730000  0.726045
# 4         0.4            69  0.790000   0.788475  0.790000  0.778339
# 5         0.4           101  0.730000   0.716707  0.730000  0.711610
# 6         0.3             7  0.733333   0.713479  0.733333  0.713359
# 7         0.3            69  0.826667   0.825368  0.826667  0.821142
# 8         0.3           101  0.773333   0.760279  0.773333  0.759103
# 9         0.2             7  0.720000   0.712393  0.720000  0.707185
# 10        0.2            69  0.880000   0.911667  0.880000  0.879429
# 11        0.2           101  0.820000   0.805513  0.820000  0.803287
#
#                                            Best Param
# 0   {'criterion': 'entropy', 'max_features': 'auto...
# 1   {'criterion': 'entropy', 'max_features': 'sqrt...
# 2   {'criterion': 'entropy', 'max_features': 'auto...
# 3   {'criterion': 'entropy', 'max_features': 'sqrt...
# 4   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 5   {'criterion': 'gini', 'max_features': 'auto', ...
# 6   {'criterion': 'gini', 'max_features': 'log2', ...
# 7   {'criterion': 'entropy', 'max_features': 'sqrt...
# 8   {'criterion': 'gini', 'max_features': 'log2', ...
# 9   {'criterion': 'gini', 'max_features': 'log2', ...
# 10  {'criterion': 'entropy', 'max_features': 'auto...
# 11  {'criterion': 'gini', 'max_features': 'log2', ...

# %%
df_H.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.806667   0.809858  0.806667  0.796633
# 0.3        0.777778   0.766375  0.777778  0.764535
# 0.4        0.750000   0.743332  0.750000  0.738665
# 0.5        0.741333   0.746671  0.741333  0.726622

# %% [markdown]
# ### Overall_rating_V3 `(MVC)` for `Active/Reflective` learners (60 Train - 40 Test) | (70 Train - 30 Test) | (80 Train - 20 Test)

# %%
temp = []
rand_states = [7,69,101]
y = training[['Overall_Rating_V3']]
X = training[['CGPA_Class',
              'Watch_Status_V3',
              'A/R_Score','Quiz','part_day_V3-1', 'part_day_V3-2', 'part_day_V3-3', 'part_day_V3-4']]

oversample = RandomOverSampler(sampling_strategy='all')
X, y = oversample.fit_resample(X, y)


for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {'n_estimators': [200, 400],
                      'max_features': ['auto', 'sqrt', 'log2'],
                      'criterion' :['gini', 'entropy']}

        model = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, n_jobs=-1, cv=10, verbose=1)
        model.fit(X_train, y_train.values.ravel())
        pred = model.predict(X_test)
        
        acc = accuracy_score(y_test,pred)
        pre = precision_score(y_test, pred, average='weighted')
        recall = recall_score(y_test, pred, average='weighted')
        f1 = f1_score(y_test, pred, average='weighted')
        param = model.best_params_
        
        temp.append([i,j,acc,pre,recall,f1,param])
        
df_I = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score','Best Param'],data=temp)
df_I
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#     Test Size  Random State  Accuracy  Precision    Recall  F1 Score  \
# 0         0.5             7  0.720000   0.721876  0.720000  0.718409
# 1         0.5            69  0.760000   0.763064  0.760000  0.753199
# 2         0.5           101  0.773333   0.775248  0.773333  0.772926
# 3         0.4             7  0.766667   0.765979  0.766667  0.764267
# 4         0.4            69  0.758333   0.750497  0.758333  0.751562
# 5         0.4           101  0.841667   0.835552  0.841667  0.833545
# 6         0.3             7  0.788889   0.791013  0.788889  0.783397
# 7         0.3            69  0.833333   0.832655  0.833333  0.828864
# 8         0.3           101  0.855556   0.856058  0.855556  0.855556
# 9         0.2             7  0.916667   0.913757  0.916667  0.914603
# 10        0.2            69  0.833333   0.845791  0.833333  0.822403
# 11        0.2           101  0.883333   0.898485  0.883333  0.886858
#
#                                            Best Param
# 0   {'criterion': 'gini', 'max_features': 'auto', ...
# 1   {'criterion': 'entropy', 'max_features': 'auto...
# 2   {'criterion': 'gini', 'max_features': 'auto', ...
# 3   {'criterion': 'entropy', 'max_features': 'auto...
# 4   {'criterion': 'gini', 'max_features': 'auto', ...
# 5   {'criterion': 'gini', 'max_features': 'auto', ...
# 6   {'criterion': 'entropy', 'max_features': 'auto...
# 7   {'criterion': 'gini', 'max_features': 'auto', ...
# 8   {'criterion': 'entropy', 'max_features': 'sqrt...
# 9   {'criterion': 'entropy', 'max_features': 'auto...
# 10  {'criterion': 'gini', 'max_features': 'auto', ...
# 11  {'criterion': 'gini', 'max_features': 'auto', ...

# %%
df_I.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.877778   0.886011  0.877778  0.874621
# 0.3        0.825926   0.826575  0.825926  0.822605
# 0.4        0.788889   0.784009  0.788889  0.783125
# 0.5        0.751111   0.753396  0.751111  0.748178

# %% [markdown]
# ### Overall_rating_V3 `(MVC)` for `Sensing/Intuitive` learners (60 Train - 40 Test) | (70 Train - 30 Test) | (80 Train - 20 Test)

# %%
temp = []
rand_states = [7,69,101]
y = training[['Overall_Rating_V3']]
X = training[['CGPA_Class',
              'Watch_Status_V3',
              'S/I_Score','Quiz','part_day_V3-1', 'part_day_V3-2', 'part_day_V3-3', 'part_day_V3-4']]

oversample = RandomOverSampler(sampling_strategy='all')
X, y = oversample.fit_resample(X, y)


for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {'n_estimators': [200, 400],
                      'max_features': ['auto', 'sqrt', 'log2'],
                      'criterion' :['gini', 'entropy']}

        model = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, n_jobs=-1, cv=10, verbose=1)
        model.fit(X_train, y_train.values.ravel())
        pred = model.predict(X_test)
        
        acc = accuracy_score(y_test,pred)
        pre = precision_score(y_test, pred, average='weighted')
        recall = recall_score(y_test, pred, average='weighted')
        f1 = f1_score(y_test, pred, average='weighted')
        param = model.best_params_
        
        temp.append([i,j,acc,pre,recall,f1,param])
        
df_J = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score','Best Param'],data=temp)
df_J
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#     Test Size  Random State  Accuracy  Precision    Recall  F1 Score  \
# 0         0.5             7  0.733333   0.749248  0.733333  0.730810
# 1         0.5            69  0.793333   0.783122  0.793333  0.779174
# 2         0.5           101  0.820000   0.807049  0.820000  0.804649
# 3         0.4             7  0.866667   0.861023  0.866667  0.862864
# 4         0.4            69  0.850000   0.888598  0.850000  0.825188
# 5         0.4           101  0.816667   0.797345  0.816667  0.801097
# 6         0.3             7  0.877778   0.875437  0.877778  0.876379
# 7         0.3            69  0.900000   0.908266  0.900000  0.893184
# 8         0.3           101  0.822222   0.799724  0.822222  0.805276
# 9         0.2             7  0.900000   0.911111  0.900000  0.903472
# 10        0.2            69  0.866667   0.882372  0.866667  0.857323
# 11        0.2           101  0.833333   0.825687  0.833333  0.824646
#
#                                            Best Param
# 0   {'criterion': 'gini', 'max_features': 'auto', ...
# 1   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 2   {'criterion': 'gini', 'max_features': 'auto', ...
# 3   {'criterion': 'entropy', 'max_features': 'log2...
# 4   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 5   {'criterion': 'gini', 'max_features': 'auto', ...
# 6   {'criterion': 'gini', 'max_features': 'auto', ...
# 7   {'criterion': 'gini', 'max_features': 'auto', ...
# 8   {'criterion': 'entropy', 'max_features': 'auto...
# 9   {'criterion': 'entropy', 'max_features': 'auto...
# 10  {'criterion': 'entropy', 'max_features': 'sqrt...
# 11  {'criterion': 'entropy', 'max_features': 'auto...

# %%
df_J.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.866667   0.873057  0.866667  0.861814
# 0.3        0.866667   0.861142  0.866667  0.858280
# 0.4        0.844444   0.848989  0.844444  0.829716
# 0.5        0.782222   0.779807  0.782222  0.771544

# %% [markdown]
# ### Overall_rating_V3 `(MVC)` for `Visual/Verbal` learners (60 Train - 40 Test) | (70 Train - 30 Test) | (80 Train - 20 Test)

# %%
temp = []
rand_states = [7,69,101]
y = training[['Overall_Rating_V3']]
X = training[['CGPA_Class',
              'Watch_Status_V3',
              'Vi/Vb_Score','Quiz','part_day_V3-1', 'part_day_V3-2', 'part_day_V3-3', 'part_day_V3-4']]

oversample = RandomOverSampler(sampling_strategy='all')
X, y = oversample.fit_resample(X, y)


for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {'n_estimators': [200, 400],
                      'max_features': ['auto', 'sqrt', 'log2'],
                      'criterion' :['gini', 'entropy']}

        model = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, n_jobs=-1, cv=10, verbose=1)
        model.fit(X_train, y_train.values.ravel())
        pred = model.predict(X_test)
        
        acc = accuracy_score(y_test,pred)
        pre = precision_score(y_test, pred, average='weighted')
        recall = recall_score(y_test, pred, average='weighted')
        f1 = f1_score(y_test, pred, average='weighted')
        param = model.best_params_
        
        temp.append([i,j,acc,pre,recall,f1,param])
        
df_K = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score','Best Param'],data=temp)
df_K
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#     Test Size  Random State  Accuracy  Precision    Recall  F1 Score  \
# 0         0.5             7  0.806667   0.804238  0.806667  0.803357
# 1         0.5            69  0.800000   0.794723  0.800000  0.781849
# 2         0.5           101  0.820000   0.829979  0.820000  0.819660
# 3         0.4             7  0.875000   0.870546  0.875000  0.869743
# 4         0.4            69  0.783333   0.768247  0.783333  0.772668
# 5         0.4           101  0.833333   0.833560  0.833333  0.832182
# 6         0.3             7  0.877778   0.876045  0.877778  0.876067
# 7         0.3            69  0.844444   0.833788  0.844444  0.833069
# 8         0.3           101  0.866667   0.858598  0.866667  0.859691
# 9         0.2             7  0.866667   0.867350  0.866667  0.864931
# 10        0.2            69  0.866667   0.899084  0.866667  0.849369
# 11        0.2           101  0.850000   0.840131  0.850000  0.839325
#
#                                            Best Param
# 0   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 1   {'criterion': 'gini', 'max_features': 'auto', ...
# 2   {'criterion': 'entropy', 'max_features': 'auto...
# 3   {'criterion': 'entropy', 'max_features': 'auto...
# 4   {'criterion': 'entropy', 'max_features': 'sqrt...
# 5   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 6   {'criterion': 'entropy', 'max_features': 'sqrt...
# 7   {'criterion': 'entropy', 'max_features': 'sqrt...
# 8   {'criterion': 'gini', 'max_features': 'auto', ...
# 9   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 10  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 11  {'criterion': 'entropy', 'max_features': 'sqrt...

# %%
df_K.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.861111   0.868855  0.861111  0.851208
# 0.3        0.862963   0.856143  0.862963  0.856276
# 0.4        0.830556   0.824118  0.830556  0.824864
# 0.5        0.808889   0.809646  0.808889  0.801622

# %% [markdown]
# ### Overall_rating_V3 `(MVC)` for `Sequential/Global` learners (60 Train - 40 Test) | (70 Train - 30 Test) | (80 Train - 20 Test)

# %%
temp = []
rand_states = [7,69,101]
y = training[['Overall_Rating_V3']]
X = training[['CGPA_Class',
              'Watch_Status_V3',
              'S/G_Score','Quiz','part_day_V3-1', 'part_day_V3-2', 'part_day_V3-3', 'part_day_V3-4']]

oversample = RandomOverSampler(sampling_strategy='all')
X, y = oversample.fit_resample(X, y)


for i in [0.5,0.4,0.3,0.2]:
    for j in rand_states:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=j)
        param_grid = {'n_estimators': [200, 400],
                      'max_features': ['auto', 'sqrt', 'log2'],
                      'criterion' :['gini', 'entropy']}

        model = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, n_jobs=-1, cv=10, verbose=1)
        model.fit(X_train, y_train.values.ravel())
        pred = model.predict(X_test)
        
        acc = accuracy_score(y_test,pred)
        pre = precision_score(y_test, pred, average='weighted')
        recall = recall_score(y_test, pred, average='weighted')
        f1 = f1_score(y_test, pred, average='weighted')
        param = model.best_params_
        
        temp.append([i,j,acc,pre,recall,f1,param])
        
df_L = pd.DataFrame(columns=['Test Size','Random State','Accuracy','Precision','Recall','F1 Score','Best Param'],data=temp)
df_L
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#     Test Size  Random State  Accuracy  Precision    Recall  F1 Score  \
# 0         0.5             7  0.813333   0.822021  0.813333  0.799804
# 1         0.5            69  0.800000   0.802807  0.800000  0.774007
# 2         0.5           101  0.786667   0.794562  0.786667  0.788332
# 3         0.4             7  0.808333   0.801303  0.808333  0.797570
# 4         0.4            69  0.791667   0.781775  0.791667  0.763836
# 5         0.4           101  0.816667   0.821643  0.816667  0.811816
# 6         0.3             7  0.788889   0.796189  0.788889  0.785846
# 7         0.3            69  0.855556   0.857402  0.855556  0.849241
# 8         0.3           101  0.822222   0.830061  0.822222  0.812515
# 9         0.2             7  0.883333   0.884097  0.883333  0.878395
# 10        0.2            69  0.816667   0.835849  0.816667  0.808178
# 11        0.2           101  0.833333   0.846968  0.833333  0.828470
#
#                                            Best Param
# 0   {'criterion': 'entropy', 'max_features': 'sqrt...
# 1   {'criterion': 'gini', 'max_features': 'log2', ...
# 2   {'criterion': 'gini', 'max_features': 'auto', ...
# 3   {'criterion': 'gini', 'max_features': 'auto', ...
# 4   {'criterion': 'gini', 'max_features': 'log2', ...
# 5   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 6   {'criterion': 'gini', 'max_features': 'auto', ...
# 7   {'criterion': 'entropy', 'max_features': 'auto...
# 8   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 9   {'criterion': 'gini', 'max_features': 'sqrt', ...
# 10  {'criterion': 'gini', 'max_features': 'sqrt', ...
# 11  {'criterion': 'gini', 'max_features': 'sqrt', ...

# %%
df_L.groupby('Test Size')[['Accuracy','Precision','Recall','F1 Score']].mean()
# Out:
#            Accuracy  Precision    Recall  F1 Score
# Test Size
# 0.2        0.844444   0.855638  0.844444  0.838347
# 0.3        0.822222   0.827884  0.822222  0.815868
# 0.4        0.805556   0.801574  0.805556  0.791074
# 0.5        0.800000   0.806463  0.800000  0.787381
